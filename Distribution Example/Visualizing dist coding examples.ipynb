# %%
import pandas as pd

# %%
df= pd.read_csv ('titanic.csv')

# %%
df.head()
# Out:
#   class    age     sex  survived
# 0   1st  29.00  female  survived
# 1   1st   2.00  female      died
# 2   1st  30.00    male      died
# 3   1st  25.00  female      died
# 4   1st   0.92    male  survived

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   class     756 non-null    object
#  1   age       756 non-null    float64
#  2   sex       756 non-null    object
#  3   survived  756 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 23.8+ KB

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn')
# Out:
# /var/folders/_x/n_g0v4195t34h6v_rhvdzwww0000gq/T/ipykernel_20789/240305066.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
plt.figure (figsize= (15,10))
plt.hist(df.age)
plt.xlabel('Age');

# %%
fig, ax = plt.subplots (4,3, figsize= (30,20) )
ax[0,0].hist(df.age, bins= 20)
ax[0,1].hist(df.age, bins= 5)
ax[0,2].hist(df.age, bins = 15)
ax[1,0].hist(df.age, bins = 15, alpha= 0.5)
ax[1,1].hist(df.age, bins = 15, density = True)
ax[1,2].hist(df.age, bins = 15, cumulative = True)
ax[2,0].hist(df.age, bins = 15, orientation= 'horizontal')
ax[2,1].hist(df[df['sex']=='male'].age, bins = 15, alpha = 0.7, edgecolor= 'gray')
ax[2,1].hist(df[df['sex']=='female'].age, bins = 15, alpha = 0.9, edgecolor= 'gray')
ax[2,2].hist([df[df['sex']=='male'].age, df[df['sex']=='female'].age], bins = 15, edgecolor= 'gray' , stacked= False)
ax[3,0].hist([df[df['sex']=='male'].age, df[df['sex']=='female'].age], bins = 15, edgecolor= 'gray' , stacked= True)
ax[3,1].hist(df[df['sex']=='female'].age, bins = 15, orientation= 'horizontal')
ax[3,1].hist(-df[df['sex']=='male'].age, bins = 15, orientation= 'horizontal')
ax[3,2].hist(-df[df['sex']=='male'].age, bins = 15)
ax[3,2].set_xticks(ticks= [-60, -40, -20, 0, 20, 40, 60], labels= [60, 40, 20, 0, 20, 40, 60])
ax[3,2].hist(df[df['sex']=='female'].age, bins = 15)
;
# Out:
# ''

# %% [markdown]
# ### Class Activity:
# Try to make the age pyramid?

# %%
import seaborn as sns
sns.kdeplot(df.age ,color='green',fill=True, bw_adjust= 0.8, cut= 0)
plt.xlabel ('Age');

# %%
sns.kdeplot(df[df['sex']=='male'].age ,color='green',fill=True, bw_adjust= 0.6, cut = 0)
sns.kdeplot(df[df['sex']=='female'].age ,color='blue',fill=True, bw_adjust= 0.6, cut = 0)
plt.xlabel ('Age');
