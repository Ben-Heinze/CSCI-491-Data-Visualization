# %% [markdown]
# This Folium case study was created with contributions from previous students: Alex Du Bois, Jack Kleist, and Eric Wanner-Garnier.

# %% [markdown]
# # Folium

# %% [markdown]
# Installation: py -m pip install folium

# %% [markdown]
# Folium is a Python library used for visualizing geospatial data. It is easy to use and yet a powerful library. Python Folium is wrapper for Leaflet.js which is a leading open-source JavaScript library for plotting interactive maps.
# It has the power of Leaflet.js and the simplicity of Python, which makes it an excellent tool for plotting maps. Folium is designed with simplicity, performance, and usability in mind. It works efficiently, can be extended with a lot of plugins, has a beautiful and easy-to-use API.
# Folium builds on the data wrangling strengths of the Python ecosystem and the mapping strengths of the Leaflet.js library. Manipulate your data in Python, then visualize it in a Leaflet map via Folium.

# %%
import folium
import pandas as pd
import numpy as np

# %%
#Bozeman MT (45.6815 N, 111.0320 W)

lat = 45.6815
long = -111.0320

# %%
m = folium.Map(location = [lat, long]) # simple initialization of a map, only needs this one parameter

m # 'printing' the representation of our map object
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_53302c48cd8bc1d5193c8bd43d5202c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_53302c48cd8bc1d5193c8bd43d5202c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_53302c48cd8bc1d5193c8bd43d5202c1 = L.map(
#                 &quot;map_53302c48cd8bc1d5193c8bd43d5202c1&quot;,
#                 {
#                     center: [45.6815, -111.032],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab650dbf617c46b7d4bae992b42afe3c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ab650dbf617c46b7d4bae992b42afe3c.addTo(map_53302c48cd8bc1d5193c8bd43d5202c1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#height/width
from branca.element import Figure
fig=Figure(width=550,height=350)
m = folium.Map(location = [lat, long], width=550,height=350) 
# if you send in numbers, it is interpreted as integers.  if you switch it to a string with '%' at the end, it is percentage of it's div
fig.add_child(m)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba2f103c47e9ed7c8831ef070bd2f7f1 {
#                     position: relative;
#                     width: 550.0px;
#                     height: 350.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba2f103c47e9ed7c8831ef070bd2f7f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba2f103c47e9ed7c8831ef070bd2f7f1 = L.map(
#                 &quot;map_ba2f103c47e9ed7c8831ef070bd2f7f1&quot;,
#                 {
#                     center: [45.6815, -111.032],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_429733244a2de9362a5f9c93564895e2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_429733244a2de9362a5f9c93564895e2.addTo(map_ba2f103c47e9ed7c8831ef070bd2f7f1);
#
# &lt;/script&gt;
# &lt;/html&gt;" width="550" height="350"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
#fit bounds

m = folium.Map(location=[long, lat], width=550,height=350)

folium.FitBounds(
    bounds= [[lat-1, long-1], [lat+1, long+1]] # sw, ne corners 
).add_to(m)
# this behaves similarly to zoom_start, but is probably easier to impliment if you're able to extract the range of data you're trying to display in one view.
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a969dcfc650fad1f7f3f261d9cff571d {
#                     position: relative;
#                     width: 550.0px;
#                     height: 350.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a969dcfc650fad1f7f3f261d9cff571d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a969dcfc650fad1f7f3f261d9cff571d = L.map(
#                 &quot;map_a969dcfc650fad1f7f3f261d9cff571d&quot;,
#                 {
#                     center: [-111.032, 45.6815],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca65204646ec1186537db2554c86872e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ca65204646ec1186537db2554c86872e.addTo(map_a969dcfc650fad1f7f3f261d9cff571d);
#
#
#             map_a969dcfc650fad1f7f3f261d9cff571d.fitBounds(
#                 [[44.6815, -112.032], [46.6815, -110.032]],
#                 {}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# A tileset is a collection of raster and vector data broken up into a uniform grid of square tiles. Each tileset has a different way of representing data in the map. Folium allows us to create maps with different tiles like Stamen Terrain, Stamen Toner, Stamen Water Color, CartoDB Positron, and many more. By default, the tiles are set to OpenStreetMap.
#
# Each tileset shows different features of a map and is suitable for different purposes. For example, Stamen Terrain features hill shading and natural vegetation colors. It showcases advanced labeling and linework generalization of dual-carriageway roads. And, CartoDB Dark Matter shows the CartoDB Positron map in dark mode.

# %%
#tiles

m = folium.Map(location = [lat, long], tiles='OpenStreetMap', width=1000,height=500) # default
#m = folium.Map(location= [lat, long], tiles= 'Esri.WorldTerrain', width=1000,height=500)
#m = folium.Map(location= [lat, long], tiles= 'OpenTopoMap', width=1000,height=500)

## tile sets: http://leaflet-extras.github.io/leaflet-providers/preview/  Large collection of tile sets, free for use with attribution or without with a subscription
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee95de52f761b0a5a32e22a2d468ebb5 {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee95de52f761b0a5a32e22a2d468ebb5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee95de52f761b0a5a32e22a2d468ebb5 = L.map(
#                 &quot;map_ee95de52f761b0a5a32e22a2d468ebb5&quot;,
#                 {
#                     center: [45.6815, -111.032],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88311e5adcbb05a170d46e2f8289aec1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_88311e5adcbb05a170d46e2f8289aec1.addTo(map_ee95de52f761b0a5a32e22a2d468ebb5);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location = [lat, long] , zoom_start=7, min_zoom=6 , max_zoom=10) 
folium.TileLayer('OpenStreetMap').add_to(m)
folium.TileLayer('StamenTerrain').add_to(m)
folium.TileLayer('Stamen Toner').add_to(m)
folium.TileLayer('Stamen Water Color').add_to(m)
folium.TileLayer('cartodbpositron').add_to(m)
folium.TileLayer('cartodbdark_matter').add_to(m)
folium.LayerControl().add_to(m)
m
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 3
#       1 m = folium.Map(location = [lat, long] , zoom_start=7, min_zoom=6 , max_zoom=10)
#       2 folium.TileLayer('OpenStreetMap').add_to(m)
# ----> 3 folium.TileLayer('StamenTerrain').add_to(m)
#       4 folium.TileLayer('Stamen Toner').add_to(m)
#       5 folium.TileLayer('Stamen Water Color').add_to(m)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\folium\raster_layers.py:140, in TileLayer.__init__(self, tiles, min_zoom, max_zoom, max_native_zoom, attr, detect_retina, name, overlay, control, show, no_wrap, subdomains, tms, opacity, **kwargs)
#     138 self.tiles = tiles
#     139 if not attr:
# --> 140     raise ValueError("Custom tiles must have an attribution.")
#     142 self.options = parse_options(
#     143     min_zoom=min_zoom,
#     144     max_zoom=max_zoom,
#    (...)
#     152     **kwargs,
#     153 )
#
# ValueError: Custom tiles must have an attribution.

# %%
#Simple Shapes
m = folium.Map(location= [lat, long])

folium.CircleMarker(
    location=[lat, long],
    radius = 10
).add_to(m)

folium.RegularPolygonMarker(
    location=[lat, long],
    number_of_sides=8,
    radius=150,
    fill_color = 'red'
).add_to(m)

m

# %% [markdown]
# The text when you hover over a marker is known as tooltip and the content when you click on a marker is known as a popup.

# %%
#markers
m = folium.Map(location=[45.372, -121.6972], zoom_start=12, min_zoom=10)

tooltip = "Click me!"

#standard formatting.  There are extra visualization options for this in the documentation
#you can even completely overwrite the 'marker' with an image, local or via url
folium.Marker(
    [45.3288, -121.6625], 
    popup="<i>Mt. Hood Meadows</i>",
    tooltip=tooltip
).add_to(m)

folium.Marker(
    [45.3311, -121.7113], 
    popup="<b>Timberline Lodge</b>", 
    tooltip=tooltip
).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f76dbad0d174aa918da98cf5ece839ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f76dbad0d174aa918da98cf5ece839ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f76dbad0d174aa918da98cf5ece839ae = L.map(
#                 &quot;map_f76dbad0d174aa918da98cf5ece839ae&quot;,
#                 {
#                     center: [45.372, -121.6972],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77fe5278f189ba1998acb5385a8da22f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 10, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_77fe5278f189ba1998acb5385a8da22f.addTo(map_f76dbad0d174aa918da98cf5ece839ae);
#
#
#             var marker_bc0ae5392b01fd6d243407adccbeb2a2 = L.marker(
#                 [45.3288, -121.6625],
#                 {}
#             ).addTo(map_f76dbad0d174aa918da98cf5ece839ae);
#
#
#         var popup_f6a27837bcc5ab4fa300d37d76e1bd38 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_05cd30845671340805c5e3972312db37 = $(`&lt;div id=&quot;html_05cd30845671340805c5e3972312db37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Mt. Hood Meadows&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_f6a27837bcc5ab4fa300d37d76e1bd38.setContent(html_05cd30845671340805c5e3972312db37);
#
#
#
#         marker_bc0ae5392b01fd6d243407adccbeb2a2.bindPopup(popup_f6a27837bcc5ab4fa300d37d76e1bd38)
#         ;
#
#
#
#
#             marker_bc0ae5392b01fd6d243407adccbeb2a2.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2820c9b132d8d14995655d372e4702ae = L.marker(
#                 [45.3311, -121.7113],
#                 {}
#             ).addTo(map_f76dbad0d174aa918da98cf5ece839ae);
#
#
#         var popup_6f973fa639b4f2d6351a57a977653259 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d665364d2f4df202c25f899c2518c40 = $(`&lt;div id=&quot;html_6d665364d2f4df202c25f899c2518c40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Timberline Lodge&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_6f973fa639b4f2d6351a57a977653259.setContent(html_6d665364d2f4df202c25f899c2518c40);
#
#
#
#         marker_2820c9b132d8d14995655d372e4702ae.bindPopup(popup_6f973fa639b4f2d6351a57a977653259)
#         ;
#
#
#
#
#             marker_2820c9b132d8d14995655d372e4702ae.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[45.372, -121.6972], zoom_start=12)

#simple interactable markers
m.add_child(folium.ClickForMarker(popup="Waypoint"))

#you can save the whole map object in it's HTML representation.  When opened, it still has all of its attributes and interactability.
m.save("demo.html")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_787850f47a1dd0d4d9c27eafee3d6825 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_787850f47a1dd0d4d9c27eafee3d6825&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_787850f47a1dd0d4d9c27eafee3d6825 = L.map(
#                 &quot;map_787850f47a1dd0d4d9c27eafee3d6825&quot;,
#                 {
#                     center: [45.372, -121.6972],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4864e6399b82f07bf4a6b9661efbab09 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4864e6399b82f07bf4a6b9661efbab09.addTo(map_787850f47a1dd0d4d9c27eafee3d6825);
#
#
#                 function newMarker(e){
#                     var new_mark = L.marker().setLatLng(e.latlng).addTo(map_787850f47a1dd0d4d9c27eafee3d6825);
#                     new_mark.dragging.enable();
#                     new_mark.on(&#x27;dblclick&#x27;, function(e){ map_787850f47a1dd0d4d9c27eafee3d6825.removeLayer(e.target)})
#                     var lat = e.latlng.lat.toFixed(4),
#                        lng = e.latlng.lng.toFixed(4);
#                     new_mark.bindPopup(`Waypoint`);
#                     };
#                 map_787850f47a1dd0d4d9c27eafee3d6825.on(&#x27;click&#x27;, newMarker);
#
#
#             tile_layer_4864e6399b82f07bf4a6b9661efbab09.addTo(map_787850f47a1dd0d4d9c27eafee3d6825);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Mapping the Avalanche Accidents Dataset

# %% [markdown]
# The below code drops the NA values, converts the lat, lon, and people killed to numbers, as well as replaces mistyped data with correctly typed data

# %%
avalanche_df = pd.read_csv("Avalanche_Accidents_2022_PUBLIC.csv")
avalanche_cleaned_df = avalanche_df.dropna()
avalanche_cleaned_df = avalanche_cleaned_df.set_index('Date')

# %%
avalanche_cleaned_df['lat'] = pd.to_numeric(avalanche_cleaned_df['lat'])
avalanche_cleaned_df['lon'] = pd.to_numeric(avalanche_cleaned_df['lon'])
avalanche_cleaned_df['Killed'] = pd.to_numeric(avalanche_cleaned_df['Killed'])

# %%
avalanche_cleaned_df
# Out:
#             AvyYear  YYYY  MM  DD  \
# Date
# 5/29/2022      2022  2022   5  29
# 4/25/2022      2022  2022   4  25
# 3/19/2022      2022  2022   3  19
# 3/17/2022      2022  2022   3  17
# 3/17/2022      2022  2022   3  17
# ...             ...   ...  ..  ..
# 1/21/2019      2019  2019   1  21
# 1/9/2019       2019  2019   1   9
# 1/5/2019       2019  2019   1   5
# 1/5/2019       2019  2019   1   5
# 12/22/2018     2019  2018  12  22
#
#                                                      Location Trigger  D Size  \
# Date
# 5/29/2022          Mount Meeker, Rocky Mountain National Park       N     3.0
# 4/25/2022   Ice Face, southeast of Thompson Pass, Chugach ...      AS     2.0
# 3/19/2022    North Fork of Fish Creek, near Steamboat Springs      AS     2.0
# 3/17/2022                Pilot Knob, east of Lizard Head Pass      AR     2.5
# 3/17/2022           Game Creek Drainage, east of Victor Idaho      AS     2.5
# ...                                                       ...     ...     ...
# 1/21/2019                       Green Mountain, Express Creek      AS     2.5
# 1/9/2019              Mount Leidy, southwest of Togwotee Pass      AM     2.0
# 1/5/2019    Upper Senator Beck Basin, northwest of Red Mou...      AS     2.0
# 1/5/2019             South Waldron Creek, north of Teton Peak      AM     3.0
# 12/22/2018                         Horse Creek, Wyoming Range      AM     1.5
#
#            Setting State        lat         lon     PrimaryActivity  \
# Date
# 5/29/2022       BC    CO  40.253370 -105.600944             Climber
# 4/25/2022       BC    AK  61.126299 -145.727162    Mechanised Guide
# 3/19/2022       BC    CO  40.505660 -106.720470  Backcountry Tourer
# 3/17/2022       BC    CO  37.811000 -107.838000  Backcountry Tourer
# 3/17/2022       BC    WY  43.594646 -111.011139  Backcountry Tourer
# ...            ...   ...        ...         ...                 ...
# 1/21/2019       BC    CO  39.025500 -106.785110  Backcountry Tourer
# 1/9/2019        BC    WY  43.724310 -110.405040         Snowmobiler
# 1/5/2019        BC    CO  37.914670 -107.733620  Backcountry Tourer
# 1/5/2019        BC    MT  47.925500 -112.795380         Snowmobiler
# 12/22/2018      BC    WY  42.928524 -110.525528         Snowmobiler
#
#             TravelMode  Killed  \
# Date
# 5/29/2022         Foot       1
# 4/25/2022          Ski       1
# 3/19/2022          Ski       1
# 3/17/2022    Snowboard       1
# 3/17/2022          Ski       1
# ...                ...     ...
# 1/21/2019          Ski       1
# 1/9/2019    Snowmobile       1
# 1/5/2019           Ski       1
# 1/5/2019    Snowmobile       1
# 12/22/2018  Snowmobile       1
#
#                                                   Description
# Date
# 5/29/2022   3 climbers caught, 1 partially buried, 1 injur...
# 4/25/2022      1 skier caught, carried over cliff, and killed
# 3/19/2022   1 backcountry skier caught, partially buried-c...
# 3/17/2022   1 backcountry snowboarder caught, buried, and ...
# 3/17/2022   2 skiers caught, 2 fully buried, 1 injured, an...
# ...                                                       ...
# 1/21/2019     1 backcountry tourer caught, buried, and killed
# 1/9/2019             1 snowmobiler caught, buried, and killed
# 1/5/2019    6 backcountry tourers caught, 1 partially buri...
# 1/5/2019    2 snowmobilers caught, 1 carried and injured, ...
# 12/22/2018           1 snowmobiler caught, buried, and killed
#
# [68 rows x 15 columns]

# %%
#This is finding the average lat and lon of all the points in order to decide where to start the map
avg_lat = avalanche_cleaned_df.loc[:,'lat'].mean(axis=0)
avg_lon = avalanche_cleaned_df.loc[:,'lon'].mean(axis=0)

# %%
avalanche_cleaned_df
# Out:
#             AvyYear  YYYY  MM  DD  \
# Date
# 5/29/2022      2022  2022   5  29
# 4/25/2022      2022  2022   4  25
# 3/19/2022      2022  2022   3  19
# 3/17/2022      2022  2022   3  17
# 3/17/2022      2022  2022   3  17
# ...             ...   ...  ..  ..
# 1/21/2019      2019  2019   1  21
# 1/9/2019       2019  2019   1   9
# 1/5/2019       2019  2019   1   5
# 1/5/2019       2019  2019   1   5
# 12/22/2018     2019  2018  12  22
#
#                                                      Location Trigger  D Size  \
# Date
# 5/29/2022          Mount Meeker, Rocky Mountain National Park       N     3.0
# 4/25/2022   Ice Face, southeast of Thompson Pass, Chugach ...      AS     2.0
# 3/19/2022    North Fork of Fish Creek, near Steamboat Springs      AS     2.0
# 3/17/2022                Pilot Knob, east of Lizard Head Pass      AR     2.5
# 3/17/2022           Game Creek Drainage, east of Victor Idaho      AS     2.5
# ...                                                       ...     ...     ...
# 1/21/2019                       Green Mountain, Express Creek      AS     2.5
# 1/9/2019              Mount Leidy, southwest of Togwotee Pass      AM     2.0
# 1/5/2019    Upper Senator Beck Basin, northwest of Red Mou...      AS     2.0
# 1/5/2019             South Waldron Creek, north of Teton Peak      AM     3.0
# 12/22/2018                         Horse Creek, Wyoming Range      AM     1.5
#
#            Setting State        lat         lon     PrimaryActivity  \
# Date
# 5/29/2022       BC    CO  40.253370 -105.600944             Climber
# 4/25/2022       BC    AK  61.126299 -145.727162    Mechanised Guide
# 3/19/2022       BC    CO  40.505660 -106.720470  Backcountry Tourer
# 3/17/2022       BC    CO  37.811000 -107.838000  Backcountry Tourer
# 3/17/2022       BC    WY  43.594646 -111.011139  Backcountry Tourer
# ...            ...   ...        ...         ...                 ...
# 1/21/2019       BC    CO  39.025500 -106.785110  Backcountry Tourer
# 1/9/2019        BC    WY  43.724310 -110.405040         Snowmobiler
# 1/5/2019        BC    CO  37.914670 -107.733620  Backcountry Tourer
# 1/5/2019        BC    MT  47.925500 -112.795380         Snowmobiler
# 12/22/2018      BC    WY  42.928524 -110.525528         Snowmobiler
#
#             TravelMode  Killed  \
# Date
# 5/29/2022         Foot       1
# 4/25/2022          Ski       1
# 3/19/2022          Ski       1
# 3/17/2022    Snowboard       1
# 3/17/2022          Ski       1
# ...                ...     ...
# 1/21/2019          Ski       1
# 1/9/2019    Snowmobile       1
# 1/5/2019           Ski       1
# 1/5/2019    Snowmobile       1
# 12/22/2018  Snowmobile       1
#
#                                                   Description
# Date
# 5/29/2022   3 climbers caught, 1 partially buried, 1 injur...
# 4/25/2022      1 skier caught, carried over cliff, and killed
# 3/19/2022   1 backcountry skier caught, partially buried-c...
# 3/17/2022   1 backcountry snowboarder caught, buried, and ...
# 3/17/2022   2 skiers caught, 2 fully buried, 1 injured, an...
# ...                                                       ...
# 1/21/2019     1 backcountry tourer caught, buried, and killed
# 1/9/2019             1 snowmobiler caught, buried, and killed
# 1/5/2019    6 backcountry tourers caught, 1 partially buri...
# 1/5/2019    2 snowmobilers caught, 1 carried and injured, ...
# 12/22/2018           1 snowmobiler caught, buried, and killed
#
# [68 rows x 15 columns]

# %%
#this declares the folium map and where it's located

basic_map=folium.Map(location=[avg_lat,avg_lon],zoom_start=4)
for index,row in avalanche_cleaned_df.iterrows():
    folium.Marker(location=[row['lat'],row['lon']], popup=[row['State'], row['Killed']], tooltip='More Info').add_to(basic_map)

# %%
basic_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fea8146b92acb385496d5df2996f15ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fea8146b92acb385496d5df2996f15ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fea8146b92acb385496d5df2996f15ce = L.map(
#                 &quot;map_fea8146b92acb385496d5df2996f15ce&quot;,
#                 {
#                     center: [42.79134132647059, -111.34366468235295],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07f72890857b6272de6928999be50742 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_07f72890857b6272de6928999be50742.addTo(map_fea8146b92acb385496d5df2996f15ce);
#
#
#             var marker_5d56853a095ac8995b1f88c2146622bc = L.marker(
#                 [40.25337, -105.600944],
#                 {}
#             ).addTo(map_fea8146b92acb385496d5df2996f15ce);
#
#
#         var popup_b116a67d9c0196c86fef4e388fba773c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c77cab88bceb3a48c84a2d0eb6cace09 = $(`&lt;div id=&quot;html_c77cab88bceb3a48c84a2d0eb6cace09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CO&#x27;, 1]&lt;/div&gt;`)[0];
#                 popup_b116a67d9c0196c86fef4e388fba773c.setContent(html_c77cab88bceb3a48c84a2d0eb6cace09);
#
#
#
#         marker_5d56853a095ac8995b1f88c2146622bc.bindPopup(popup_b116a67d9c0196c86fef4e388fba773c)
#         ;
#
#
#
#
#             marker_5d56853a095ac8995b1f88c2146622bc.bindTooltip(
#                 `&lt;div&gt;
#                      More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_602e5603e75fc0e1ef5751479f1c403c = L.marker(
#                 [61.1262988, -145.7271624],
#                 {}
#             ).addTo(map_fea8146b92acb385496d5df2996f15ce);
#
#
#         var popup_ecdc524e41acd2a53f88e450b224b81a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_98fb7c7f0aebffed478c5aef4d8ab3c6 = $(`&lt;div id=&quot;html_98fb7c7f0aebffed478c5aef4d8ab3c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;AK&#x27;, 1]&lt;/div&gt;`)[0];
#                 popup_ecdc524e41acd2a53f88e450b224b81a.setContent(html_98fb7c7f0aebffed478c5aef4d8ab3c6);
#
#
#
#         marker_602e5603e75fc0e1ef5751479f1c403c.bindPopup(popup_ecdc524e41acd2a53f88e450b224b81a)
#         ;
#
#
#
#
#             marker_602e5603e75fc0e1ef5751479f1c403c.bindTooltip(
#                 `&lt;div&gt;
#                      More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_295f056fa3e2b4f1907e3a97e549aa56 = L.marker(
#                 [40.50566, -106.72047],
#                 {}
#             ).addTo(map_fea8146b92acb385496d5df2996f15ce);
#
#
#         var popup_9db5e57bfcee2e7dddb1dd8cba89c2f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dbf25265ae084db19b1b6c5af1511182 = $(`&lt;div id=&quot;html_dbf25265ae084db19b1b6c5af1511182&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CO&#x27;, 1]&lt;/div&gt;`)[0];
#                 popup_9db5e57bfcee2e7dddb1dd8cba89c2f2.setContent(html_dbf25265ae084db19b1b6c5af1511182);
#
#
#
#         marker_295f056fa3e2b4f1907e3a97e549aa56.bindPopup(popup_9db5e57bfcee2e7dddb1dd8cba89c2f2)
#         ;
#
#
#
#
#             marker_295f056fa3e2b4f1907e3a97e549aa56.bindTooltip(
#                 `&lt;div&gt;
#                      More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4635f01f4d2bd60d395af2340d209463 = L.marker(
#                 [37.811, -107.838],
#                 {}
#             ).addTo(map_fea8146b92acb385496d5df2996f15ce);
#
#
#         var popup_122a8a1a2a3ced18bef78cebd521bd1e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12d20d23fb5746d3af59ec4f93162dd7 = $(`&lt;div id=&quot;html_12d20d23fb5746d3af59ec4f93162dd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;CO&#x27;, 1]&lt;/div&gt;`)[0];
#                 popup_122a8a1a2a3ced18bef78cebd521bd1e.setContent(html_12d20d23fb5746d3af59ec4f93162dd7);
#
#
#
#         marker_4635f01f4d2bd60d395af2340d209463.bindPopup(popup_122a8a1a2a3ced18bef78cebd521bd1e)
#         ;
#
#
#
#
#             marker_4635f01f4d2bd60d395af2340d209463.bindTooltip(
#                 `&lt;div&gt;
#                      More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_19b

# %% [markdown]
# # Creatingn a Choropleth

# %%
import geopandas
from folium.plugins import TimeSliderChoropleth
url = ("https://raw.githubusercontent.com/python-visualization/folium/main/examples/data")

# %%
# Select the columns of our dataset that we need, and convert the year column to a date value
avalanche_df = pd.read_csv('Avalanche_Accidents_2022_PUBLIC.csv')
avalanche_cleaned_df = avalanche_df[["AvyYear","State","Killed"]]
avalanche_cleaned_df['AvyYear'] = pd.to_datetime(avalanche_cleaned_df['AvyYear'],format='%Y')

avalanche_cleaned_df['AvyYear']
# Out:
# C:\Users\bench\AppData\Local\Temp\ipykernel_13424\2987436069.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avalanche_cleaned_df['AvyYear'] = pd.to_datetime(avalanche_cleaned_df['AvyYear'],format='%Y')
# 0     2022-01-01
# 1     2022-01-01
# 2     2022-01-01
# 3     2022-01-01
# 4     2022-01-01
#          ...
# 951   1952-01-01
# 952   1952-01-01
# 953   1952-01-01
# 954   1952-01-01
# 955   1951-01-01
# Name: AvyYear, Length: 956, dtype: datetime64[ns]

# %%
avalanche_df.head()
# Out:
#    AvyYear  YYYY  MM  DD                                           Location  \
# 0     2022  2022   5  29         Mount Meeker, Rocky Mountain National Park
# 1     2022  2022   4  25  Ice Face, southeast of Thompson Pass, Chugach ...
# 2     2022  2022   3  19   North Fork of Fish Creek, near Steamboat Springs
# 3     2022  2022   3  17               Pilot Knob, east of Lizard Head Pass
# 4     2022  2022   3  17          Game Creek Drainage, east of Victor Idaho
#
#   Trigger  D Size Setting State         lat           lon     PrimaryActivity  \
# 0       N     3.0      BC    CO    40.25337   -105.600944             Climber
# 1      AS     2.0      BC    AK  61.1262988  -145.7271624    Mechanised Guide
# 2      AS     2.0      BC    CO    40.50566    -106.72047  Backcountry Tourer
# 3      AR     2.5      BC    CO      37.811      -107.838  Backcountry Tourer
# 4      AS     2.5      BC    WY   43.594646   -111.011139  Backcountry Tourer
#
#   TravelMode  Killed                                        Description  \
# 0       Foot       1  3 climbers caught, 1 partially buried, 1 injur...
# 1        Ski       1     1 skier caught, carried over cliff, and killed
# 2        Ski       1  1 backcountry skier caught, partially buried-c...
# 3  Snowboard       1  1 backcountry snowboarder caught, buried, and ...
# 4        Ski       1  2 skiers caught, 2 fully buried, 1 injured, an...
#
#         Date
# 0  5/29/2022
# 1  4/25/2022
# 2  3/19/2022
# 3  3/17/2022
# 4  3/17/2022

# %%
# Reformat date column to U10, as that is the format the choropleth function expects
avalanche_cleaned_df['AvyYear']=(avalanche_cleaned_df['AvyYear'].astype(int)//10**9).astype("U10")
avalanche_cleaned_df['AvyYear']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 # Reformat date column to U10, as that is the format the choropleth function expects
# ----> 2 avalanche_cleaned_df['AvyYear']=(avalanche_cleaned_df['AvyYear'].astype(int)//10**9).astype("U10")
#       3 avalanche_cleaned_df['AvyYear']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\dtypes\astype.py:179, in astype_array(values, dtype, copy)
#     175     return values
#     177 if not isinstance(values, np.ndarray):
#     178     # i.e. ExtensionArray
# --> 179     values = values.astype(dtype, copy=copy)
#     181 else:
#     182     values = _astype_nansafe(values, dtype, copy=copy)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\arrays\datetimes.py:739, in DatetimeArray.astype(self, dtype, copy)
#     737 elif isinstance(dtype, PeriodDtype):
#     738     return self.to_period(freq=dtype.freq)
# --> 739 return dtl.DatetimeLikeArrayMixin.astype(self, dtype, copy)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\arrays\datetimelike.py:482, in DatetimeLikeArrayMixin.astype(self, dtype, copy)
#     480 values = self.asi8
#     481 if dtype != np.int64:
# --> 482     raise TypeError(
#     483         f"Converting from {self.dtype} to {dtype} is not supported. "
#     484         "Do obj.astype('int64').astype(dtype) instead"
#     485     )
#     487 if copy:
#     488     values = values.copy()
#
# TypeError: Converting from datetime64[ns] to int32 is not supported. Do obj.astype('int64').astype(dtype) instead

# %%
# Group the data by state and year
grouped_avy_df = avalanche_cleaned_df.groupby(["AvyYear","State"])["Killed"].sum()
new_grouped_avy_df = grouped_avy_df.reset_index()
bins=np.linspace(min(new_grouped_avy_df['Killed']),max(new_grouped_avy_df['Killed']),12)
bins

new_grouped_avy_df.head()

# %%
# Create color data for each data point for display on our map 
from branca.colormap import linear

cmap = linear.BuPu_06.scale(1, 12)

killedSeries = pd.Series(new_grouped_avy_df["Killed"], copy=False)
killedSeries = killedSeries.apply(cmap)
new_grouped_avy_df["Color"] = killedSeries

new_grouped_avy_df.head()

# %%
# Gather geography data for each state
state_geo = geopandas.read_file(f"{url}/us-states.json")

state_geo.head()

# %%
# Create style dictionary for the map - associating each state location with a number of deaths & color
avy_dict={}

for state in new_grouped_avy_df['State'].unique():
    avy_dict[state] = {}
    for j in new_grouped_avy_df[new_grouped_avy_df["State"]==state].set_index('State').values:
        avy_dict[state][j[0]]={'color':j[2],'opacity':.8}

# %%
# Create choropleth - create map and then add a time slider and a legend
m = folium.Map(location=[48,-102],height=850,width=1000, zoom_start=3, max_zoom=6, min_zoom=4)

folium.TileLayer('Stamen Terrain').add_to(m)

TimeSliderChoropleth(
    state_geo.set_index('id').to_json(),
    styledict=avy_dict
).add_to(m)

folium.Choropleth(
    geo_data=state_geo.set_index('id').to_json(),
    data=new_grouped_avy_df,
    columns=['AvyYear', 'Killed'],
    key_on='feature.id',
    fill_color= 'BuPu',
    fill_opacity=0.0,
    line_opacity=0.0,
    legend_name='Deaths'
).add_to(m)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 4
#       1 # Create choropleth - create map and then add a time slider and a legend
#       2 m = folium.Map(location=[48,-102],height=850,width=1000, zoom_start=3, max_zoom=6, min_zoom=4)
# ----> 4 folium.TileLayer('Stamen Terrain').add_to(m)
#       6 TimeSliderChoropleth(
#       7     state_geo.set_index('id').to_json(),
#       8     styledict=avy_dict
#       9 ).add_to(m)
#      11 folium.Choropleth(
#      12     geo_data=state_geo.set_index('id').to_json(),
#      13     data=new_grouped_avy_df,
#    (...)
#      19     legend_name='Deaths'
#      20 ).add_to(m)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\folium\raster_layers.py:140, in TileLayer.__init__(self, tiles, min_zoom, max_zoom, max_native_zoom, attr, detect_retina, name, overlay, control, show, no_wrap, subdomains, tms, opacity, **kwargs)
#     138 self.tiles = tiles
#     139 if not attr:
# --> 140     raise ValueError("Custom tiles must have an attribution.")
#     142 self.options = parse_options(
#     143     min_zoom=min_zoom,
#     144     max_zoom=max_zoom,
#    (...)
#     152     **kwargs,
#     153 )
#
# ValueError: Custom tiles must have an attribution.

# %%
# Display map
m
